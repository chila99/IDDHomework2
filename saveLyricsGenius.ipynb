# %%
from lyricsgenius import Genius
import lyricsgenius

# %%
import unicodedata
import re

def slugify(value, allow_unicode=False):
    """
    Taken from https://github.com/django/django/blob/master/django/utils/text.py
    Convert to ASCII if 'allow_unicode' is False. Convert spaces or repeated
    dashes to single dashes. Remove characters that aren't alphanumerics,
    underscores, or hyphens. Convert to lowercase. Also strip leading and
    trailing whitespace, dashes, and underscores.
    """
    value = str(value)
    if allow_unicode:
        value = unicodedata.normalize('NFKC', value)
    else:
        value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
    return re.sub(r'[^\w\s-]', ' ', value)

# %%
genius = lyricsgenius.Genius("yRY8YHVjg8PrAHCBOrWzNyRJcSMNVs7SAtJeiyww2DJ3MSf3wG8GZc8_-GjmYPWu", verbose=True, remove_section_headers=True, skip_non_songs=True, retries=5, timeout=120)
artists = ["Imagine Dragons", "Ed Sheeran" "Justin Bieber", "AC/DC", "Bad Bunny", "Beyonce", "Tiziano Ferro"]
for artist in artists:
    retrievedArtist = genius.search_artist(artist, max_songs=100, get_full_info=False)
    for song in retrievedArtist.songs:
        with open('../songs/'+ slugify(song.title) + '.txt', 'w') as f:
            f.write(retrievedArtist.name +"\n")
            f.write(song.lyrics)
# Out:
# Searching for songs by Imagine Dragons...
#
# Song 1: "Believer"
# Song 2: "Thunder"
# Song 3: "Demons"
# Song 4: "Whatever It Takes"
# Song 5: "Radioactive"
# Song 6: "Natural"
# Song 7: "Bad Liar"
# Song 8: "Radioactive (Remix)"
# Song 9: "Not Today"
# Song 10: "Next to Me"
# Song 11: "It’s Time"
# Song 12: "Walking the Wire"
# Song 13: "Zero"
# Song 14: "Warriors"
# Song 15: "On Top of the World"
# Song 16: "Rise Up"
# Song 17: "I Don’t Know Why"
# Song 18: "Birds"
# Song 19: "Follow You"
# Song 20: "Enemy (Solo Mix)"
# Song 21: "I’m So Sorry"
# Song 22: "Machine"
# Song 23: "Shots"
# Song 24: "I Bet My Life"
# Song 25: "Monster"
# Song 26: "Believer (Remix)"
# Song 27: "Amsterdam"
# Song 28: "Dream"
# Song 29: "Bones"
# Song 30: "Polaroid"
# Song 31: "Bleeding Out"
# Song 32: "West Coast"
# Song 33: "Gold"
# Song 34: "Roots"
# Song 35: "I’ll Make It Up to You"
# Song 36: "Friction"
# Song 37: "Dancing in the Dark"
# Song 38: "Boomerang"
# Song 39: "Yesterday"
# Song 40: "Sharks"
# Song 41: "Mouth of the River"
# Song 42: "Wrecked"
# Song 43: "Bullet in a Gun"
# Song 44: "Nothing Left to Say / Rocks"
# Song 45: "Cool Out"
# Song 46: "Smoke and Mirrors"
# Song 47: "Cutthroat"
# Song 48: "Burn Out"
# Song 49: "Battle Cry"
# Song 50: "Love"
# Song 51: "Start Over"
# Song 52: "My Life"
# Song 53: "Hopeless Opus"
# Song 54: "Tiptoe"
# Song 55: "Hear Me"
# Song 56: "Lonely"
# Song 57: "Real Life"
# Song 58: "Stuck"
# Song 59: "Giants"
# Song 60: "Digital"
# Song 61: "Dull Knives"
# Song 62: "Who We Are"
# Song 63: "Only"
# Song 64: "It’s Ok"
# Song 65: "Levitate"
# Song 66: "Easy Come Easy Go"
# Song 67: "Monday"
# Song 68: "#1"
# Song 69: "It Comes Back to You"
# Song 70: "The Fall"
# Song 71: "No Time For Toxic People"
# Song 72: "Mad World"
# Song 73: "One Day"
# Song 74: "America"
# Song 75: "Round and Round"
# Song 76: "Trouble"
# Song 77: "Selene"
# Song 78: "Every Night"
# Song 79: "Underdog"
# Song 80: "Summer"
# Song 81: "Ready Aim Fire"
# Song 82: "Shots (Broiler Remix)"
# Song 83: "I Was Me"
# Song 84: "Release"
# Song 85: "Second Chances"
# Song 86: "Waves"
# Song 87: "Thief"
# Song 88: "Believer (Kaskade Remix)"
# Song 89: "Cha-Ching (Till We Grow Older)"
# Song 90: "I Don’t Like Myself"
# Song 91: "Symphony"
# Song 92: "The River"
# Song 93: "My Fault"
# Song 94: "Blank Space/Stand By Me (Live From Spotify London)"
# Song 95: "They Don’t Know You Like I Do"
# Song 96: "Tokyo"
# Song 97: "The Unknown"
# Song 98: "Higher Ground"
# Song 99: "Crushed"
# Song 100: "Working Man"
#
# Reached user-specified song limit (100).
# Done. Found 100 songs.
# Searching for songs by Ed SheeranJustin Bieber...
#
# Changing artist name to 'Ed Sheeran & Justin Bieber'
# Song 1: "I Don’t Care"
# Song 2: "I Don’t Care (Chronixx & Koffee Remix)"
# Song 3: "I Don’t Care (Jonas Blue Remix)"
# Song 4: "I Don’t Care (Loud Luxury Remix)"
# Done. Found 4 songs.
# Searching for songs by AC/DC...
#
# Song 1: "Back in Black"
# Song 2: "T.N.T."
# Song 3: "Highway to Hell"
# Song 4: "Thunderstruck"
# Song 5: "You Shook Me All Night Long"
# Song 6: "Big Balls"
# Song 7: "Dirty Deeds Done Dirt Cheap"
# Song 8: "Hells Bells"
# Song 9: "Shoot to Thrill"
# Song 10: "Shot in the Dark"
# Song 11: "It’s a Long Way to the Top (If You Wanna Rock n’ Roll)"
# Song 12: "Whole Lotta Rosie"
# Song 13: "The Jack"
# Song 14: "Let There Be Rock"
# Song 15: "Have a Drink on Me"
# Song 16: "Touch Too Much"
# Song 17: "Moneytalks"
# Song 18: "For Those About to Rock (We Salute You)"
# Song 19: "Through the Mists of Time"
# Song 20: "Givin’ the Dog a Bone"
# Song 21: "Rock and Roll Ain’t Noise Pollution"
# Song 22: "Who Made Who"
# Song 23: "Live Wire"
# Song 24: "Let Me Put My Love Into You"
# Song 25: "Rock N’ Roll Train"
# Song 26: "Girls Got Rhythm"
# Song 27: "Problem Child"
# Song 28: "If You Want Blood (You’ve Got It)"
# Song 29: "Ride On"
# Song 30: "Realize"
# Song 31: "Demon Fire"
# Song 32: "High Voltage"
# Song 33: "Night Prowler"
# Song 34: "What Do You Do for Money Honey"
# Song 35: "Sin City"
# Song 36: "Jailbreak"
# Song 37: "Shake a Leg"
# Song 38: "Are You Ready"
# Song 39: "Hell Ain’t a Bad Place to Be"
# Song 40: "Walk All Over You"
# Song 41: "Shot Down in Flames"
# Song 42: "Money Shot"
# Song 43: "Riff Raff"
# Song 44: "Rejection"
# Song 45: "War Machine"
# Song 46: "Witch’s Spell"
# Song 47: "Ballbreaker"
# Song 48: "Stiff Upper Lip"
# Song 49: "Gone Shootin’"
# Song 50: "Kick You When You’re Down"
# Song 51: "Rock ‘n’ Roll Singer"
# Song 52: "Beating Around the Bush"
# Song 53: "She’s Got Balls"
# Song 54: "Rock or Bust"
# Song 55: "The Razors Edge"
# Song 56: "Code Red"
# Song 57: "Rock ‘N’ Roll Damnation"
# Song 58: "Hail Caesar"
# Song 59: "Hard as a Rock"
# Song 60: "Big Gun"
# Song 61: "Squealer"
# Song 62: "Rocker"
# Song 63: "Dog Eat Dog"
# Song 64: "Little Lover"
# Song 65: "Mistress For Christmas"
# Song 66: "Ain’t No Fun (Waiting ’Round to Be a Millionaire)"
# Song 67: "Down Payment Blues"
# Song 68: "Wild Reputation"
# Song 69: "Sink the Pink"
# Song 70: "Black Ice"
# Song 71: "Overdose"
# Song 72: "Systems Down"
# Song 73: "What’s Next to the Moon"
# Song 74: "Can I Sit Next to You Girl"
# Song 75: "No Man’s Land"
# Song 76: "Safe in New York City"
# Song 77: "Go Down"
# Song 78: "Fire Your Guns"
# Song 79: "Get It Hot"
# Song 80: "Love Hungry Man"
# Song 81: "Bad Boy Boogie"
# Song 82: "Let’s Get It Up"
# Song 83: "Gimme a Bullet"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Ac-dc-dt-lyrics
# Song 84: "D.T."
# Song 85: "Kicked in the Teeth"
# Song 86: "Evil Walks"
# Song 87: "Cold Hearted Man"
# Song 88: "Big Jack"
# Song 89: "Heatseeker"
# Song 90: "Flick of the Switch"
# Song 91: "That’s the Way I Wanna Rock ‘N’ Roll"
# Song 92: "Night of the Long Knives"
# Song 93: "C.O.D."
# Song 94: "Love Song"
# Song 95: "School Days"
# Song 96: "Shake Your Foundations"
# Song 97: "Baby, Please Don’t Go"
# Song 98: "Love at First Feel"
# Song 99: "Up to My Neck in You"
# Song 100: "Got You by the Balls"
#
# Reached user-specified song limit (100).
# Done. Found 100 songs.
# Searching for songs by Bad Bunny...
#
# Song 1: "Amorfoda"
# Song 2: "Tú No Metes Cabra"
# Song 3: "Yonaguni"
# Song 4: "MIA"
# Song 5: "Chambea"
# Song 6: "Soy Peor"
# Song 7: "Si Veo a Tu Mamá"
# Song 8: "Tú No Metes Cabra (Remix)"
# Song 9: "Vete"
# Song 10: "Tití Me Preguntó"
# Song 11: "Estamos Bien"
# Song 12: "Yo Perreo Sola"
# Song 13: "25/8"
# Song 14: "La Difícil"
# Song 15: "Dime Si Te Acuerdas"
# Song 16: "Otra Noche en Miami"
# Song 17: "BOOKER T"
# Song 18: "La Romana"
# Song 19: "HACIENDO QUE ME AMAS"
# Song 20: "Moscow Mule"
# Song 21: "A Tu Merced"
# Song 22: "﹤3"
# Song 23: "Si Estuviésemos Juntos"
# Song 24: "Un Verano Sin Ti"
# Song 25: "Soy Peor (Remix)"
# Song 26: "TE MUDASTE"
# Song 27: "NI BIEN NI MAL"
# Song 28: "Efecto"
# Song 29: "Solo de Mí"
# Song 30: "Me Fui de Vacaciones"
# Song 31: "Pa Ti"
# Song 32: "Yo No Soy Celoso"
# Song 33: "BYE ME FUI"
# Song 34: "Después de la Playa"
# Song 35: "De Museo"
# Song 36: "Diles"
# Song 37: "Pero Ya No"
# Song 38: "YO VISTO ASÍ"
# Song 39: "ANTES QUE SE ACABE"
# Song 40: "Soliá"
# Song 41: "RLNDT"
# Song 42: "Un Coco"
# Song 43: "Aguacero"
# Song 44: "Caro"
# Song 45: "El Apagón"
# Song 46: "EN CASITA"
# Song 47: "TE DESEO LO MEJOR"
# Song 48: "Dos Mil 16"
# Song 49: "RONCA FREESTYLE"
# Song 50: "TRELLAS"
# Song 51: "Neverita"
# Song 52: "120"
# Song 53: "HOY COBRÉ"
# Song 54: "LA DROGA"
# Song 55: "200 MPH"
# Song 56: "MALDITA POBREZA"
# Song 57: "Un Ratito"
# Song 58: "La Zona"
# Song 59: "EL MUNDO ES MÍO"
# Song 60: "BENDICIONES"
# Song 61: "Como Antes"
# Song 62: "¿Quién Tú Eres?"
# Song 63: "Enséñame a Bailar"
# Song 64: "SI ELLA SALE"
# Song 65: "Agosto"
# Song 66: "Dime Si Vas A Volver"
# Song 67: "Ser Bichote"
# Song 68: "COMPOSITOR DEL AÑO"
# Song 69: "6 Rings"
# Song 70: "Cuando Perriabas"
# Song 71: "Pa’ Que Le De (Remix)"
# Song 72: "Tenemos Que Hablar"
# Song 73: "Contigo"
# Song 74: "Me Llueven 3.0"
# Song 75: "Desde el Corazón"
# Song 76: "Me Importa Un Carajo"
# Song 77: "La T-Shirt De Biggie"
# Song 78: "Vamos Pa’ La Calle (Remix)"
# Song 79: "Solo Avísame"
# Song 80: "La Vida"
# Song 81: "CYNH2"
# Song 82: "No Prometo Nada*"
# Song 83: "Tú Me Gustas*"
# Song 84: "Soy Peor (Mambo Remix)"
# "Yo Pago" is not valid. Skipping.
# Song 85: "Me Rolie (Mami No Sé)"
# Song 86: "Me Llueven 2"
# Song 87: "25/8 (Versión Extendida)"
# Song 88: "Mood (Freestyle)"
# Song 89: "Pa’ Que Le De"
# Song 90: "El Freestyle"
# Song 91: "Es Tiempo"
# Song 92: "No Voy a Cambiar*"
# Song 93: "Mi Puerto Rico"
# Song 94: "Soy Culpable"
# Song 95: "El Chapo (Freestyle)"
# Song 96: "Un Coco (Concert Version)"
# Song 97: "Get"
# Song 98: "Alta Moda*"
# Song 99: "Me Llueven (Extended Version)"
# "Tormenta" is not valid. Skipping.
# Song 100: "Hot Nigga (Freestyle)"
#
# Reached user-specified song limit (100).
# Done. Found 100 songs.
# Searching for songs by Beyonce...
#
# Changing artist name to 'Beyoncé'
# Song 1: "Drunk in Love"
# Song 2: "Formation"
# Song 3: "Partition"
# Song 4: "Mine"
# Song 5: "Halo"
# Song 6: "Hold Up"
# Song 7: "If I Were a Boy"
# Song 8: "***Flawless (Remix)"
# Song 9: "Sorry"
# Song 10: "Pray You Catch Me"
# Song 11: "All Night"
# Song 12: "***Flawless"
# Song 13: "Freedom"
# Song 14: "Don’t Hurt Yourself"
# Song 15: "Blow"
# Song 16: "Rocket"
# Song 17: "Sandcastles"
# Song 18: "Listen"
# Song 19: "7/11"
# Song 20: "6 Inch"
# Song 21: "Love Drought"
# Song 22: "Pretty Hurts"
# Song 23: "Drunk in Love (Remix)"
# Song 24: "XO"
# Song 25: "Countdown"
# Song 26: "Haunted"
# Song 27: "Daddy Lessons"
# Song 28: "Irreplaceable"
# Song 29: "Heaven"
# Song 30: "Jealous"
# Song 31: "Crazy in Love"
# Song 32: "Bow Down / I Been On"
# Song 33: "BLACK PARADE"
# Song 34: "MOOD 4 EVA"
# Song 35: "BREAK MY SOUL"
# Song 36: "Forward"
# Song 37: "Blue"
# Song 38: "Upgrade U"
# Song 39: "Lemonade Film (Script)"
# Song 40: "HEATED"
# Song 41: "Superpower"
# Song 42: "Love on Top"
# Song 43: "Grown Woman"
# Song 44: "No Angel"
# Song 45: "Single Ladies (Put a Ring on It)"
# Song 46: "Best Thing I Never Had"
# Song 47: "Me, Myself and I"
# Song 48: "Resentment"
# Song 49: "Party"
# Song 50: "Run the World (Girls)"
# Song 51: "SPIRIT"
# Song 52: "Dance for You"
# Song 53: "Ave Maria"
# Song 54: "Back to Black"
# Song 55: "Die With You"
# Song 56: "ALIEN SUPERSTAR"
# Song 57: "I Miss You"
# Song 58: "Ego"
# Song 59: "CHURCH GIRL"
# Song 60: "Yoncé"
# Song 61: "Sweet Dreams"
# Song 62: "1+1"
# Song 63: "Dangerously In Love"
# Song 64: "I Was Here"
# Song 65: "Before I Let Go"
# Song 66: "Diva"
# Song 67: "BIGGER"
# Song 68: "Broken-Hearted Girl"
# Song 69: "Baby Boy"
# Song 70: "I’M THAT GIRL"
# Song 71: "Denial (Lemonade Poem, Part 2)"
# Song 72: "MY POWER"
# Song 73: "Hello"
# Song 74: "CUFF IT"
# Song 75: "COZY"
# Song 76: "Déjà Vu"
# Song 77: "Ring the Alarm"
# Song 78: "Kitty Kat"
# Song 79: "I’d Rather Go Blind"
# Song 80: "Ego (Remix)"
# Song 81: "ENERGY"
# Song 82: "THIQUE"
# Song 83: "Roc"
# Song 84: "AMERICA HAS A PROBLEM"
# Song 85: "OTHERSIDE"
# Song 86: "VIRGO’S GROOVE"
# Song 87: "SUMMER RENAISSANCE"
# Song 88: "Signs"
# Song 89: "PURE/HONEY"
# Song 90: "I Care"
# Song 91: "MOVE"
# Song 92: "PLASTIC OFF THE SOFA"
# Song 93: "FIND YOUR WAY BACK"
# Song 94: "End of Time"
# Song 95: "Schoolin’ Life"
# Song 96: "Wake Up"
# Song 97: "Naughty Girl"
# Song 98: "Ring Off"
# Song 99: "Check on It (LP Version)"
# Song 100: "Party (Remix)"
#
# Reached user-specified song limit (100).
# Done. Found 100 songs.
# Searching for songs by Tiziano Ferro...
#
# Song 1: "Sere nere"
# Song 2: "Il regalo più grande"
# Song 3: "Ti scatterò una foto"
# Song 4: "Non me lo so spiegare"
# Song 5: "Tardes Negras"
# Song 6: "L’ultima notte al mondo"
# Song 7: "Perdono"
# Song 8: "Potremmo Ritornare"
# Song 9: "Breathe Gentle"
# Song 10: "Accetto Miracoli"
# Song 11: "Rosso Relativo"
# Song 12: "Perdono (English Version)"
# Song 13: "Hai delle Isole negli Occhi"
# Song 14: "Ed ero contentissimo"
# Song 15: "Alla Mia Età"
# Song 16: "Indietro"
# Song 17: "Imbranato"
# Song 18: "Incanto"
# Song 19: "Il Conforto"
# Song 20: "La Fine"
# Song 21: "Xdono"
# Song 22: "La Differenza Tra Me E Te"
# Song 23: "Alucinado"
# Song 24: "Ti voglio bene"
# Song 25: "Lento/Veloce"
# Song 26: "Lento / Veloz"
# Song 27: "In Mezzo A Questo Inverno"
# Song 28: "Buona (Cattiva) Sorte"
# Song 29: "E Fuori è Buio"
# Song 30: "Amigos Por Errores"
# Song 31: "Il Sole Esiste per Tutti"
# Song 32: "L’Amore È Una Cosa Semplice"
# Song 33: "Per Dirti Ciao!"
# Song 34: "Il Mestiere Della Vita"
# Song 35: "Scivoli Di Nuovo"
# Song 36: "Balla Per Me"
# Song 37: "Perdona"
# Song 38: "Stop! Dimentica"
# Song 39: "Valore Assoluto"
# Song 40: "No Me Lo Puedo Explicar"
# Song 41: "Troppo Buono"
# Song 42: "Amici Per Errore"
# Song 43: "Lo stadio"
# Song 44: "El Regalo Más Grande (Amaia Version)"
# Song 45: "Each Tear"
# Song 46: "“Solo” È Solo Una Parola"
# Song 47: "El amor es una cosa simple [Latin America Version]"
# Song 48: "Xverso"
# Song 49: "Angelo Mio"
# Song 50: "Perverso"
# Song 51: "El Regalo Más Grande (RBD Version)"
# Song 52: "Senza Scappare Mai Più"
# Song 53: "Il Destino Di Chi Visse Per Amare"
# Song 54: "Vai ad Amarti"
# Song 55: "Centoundici"
# Song 56: "Le 3 Parole Sono 2"
# Song 57: "Le Cose Che Non Dici"
# Song 58: "Te Tomare Una Foto"
# Song 59: "A Mi Edad"
# Song 60: "Y Estaba Contentisimo"
# Song 61: "E Raffaella È Mia"
# Song 62: "Fotografie Della Tua Assenza"
# Song 63: "Casa A Natale"
# Song 64: "Rojo Relativo"
# Song 65: "Come Farebbe Un Uomo"
# Song 66: "Acepto Milagros"
# Song 67: "Desde Mañana No Lo Sé (Ti Voglio Bene)"
# Song 68: "Difendimi per sempre - demo"
# Song 69: "Salutandotiaffogo"
# Song 70: "Mia nonna"
# Song 71: "10 piegamenti!"
# Song 72: "Epic"
# Song 73: "Seconda Pelle"
# Song 74: "Podríamos Regresar"
# Song 75: "La Paura Non Esiste"
# Song 76: "Eri come l’oro ora sei come loro"
# Song 77: "La Tua Vita Non Passerà"
# Song 78: "La Paura Che..."
# Song 79: "In bagno in aeroporto"
# Song 80: "Rimmel"
# Song 81: "Tarantola d’Africa"
# Song 82: "Già Ti Guarda Alice"
# Song 83: "Morirò D’Amore"
# Song 84: "Un Uomo Pop"
# Song 85: "My Steelo"
# Song 86: "Xdono (Perdono)"
# Song 87: "Smeraldo"
# Song 88: "Quando ritornerai"
# Song 89: "Chi non ha talento insegna"
# Song 90: "Mai Nata"
# Song 91: "E Ti Vengo A Cercare"
# Song 92: "L’Olimpiade"
# Song 93: "Assurdo Pensare"
# Song 94: "Buena (Mala) Suerte"
# Song 95: "Per Un Po’ Sparirò"
# Song 96: "Ora Perdona"
# Song 97: "Mio fratello"
# Song 98: "Perdono (French Version)"
# Song 99: "Il Tempo Stesso"
# Song 100: ". . . Ma So Proteggerti"
#
# Reached user-specified song limit (100).
# Done. Found 100 songs.
